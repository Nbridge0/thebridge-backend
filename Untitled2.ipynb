# %%
from datetime import datetime
datetime.fromisoformat("2026-01-19T15:10:12Z")
# Out:
# datetime.datetime(2026, 1, 19, 15, 10, 12, tzinfo=datetime.timezone.utc)

# %%
datetime.fromisoformat("2026-01-19T15:10:12+00:00")
# Out:
# datetime.datetime(2026, 1, 19, 15, 10, 12, tzinfo=datetime.timezone.utc)
